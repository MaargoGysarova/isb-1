# %% [markdown]
# Исходный текст

# %%
TEXT = "7ОУ8cr8ЛБ8ЧХОДХЛМtcbЛrАc<МАcРcМАЕc<ХЛД8cХcБАc5МА1c БКХ<Хr8cКД8cr8cБК87ЛМОРДb8МЛbcАБМХЕОД4r ЕcОД>АКХМЕАЕcЛУОМХb?cБАЛ2АД42tcАrcr8cХЛБАД4Фt8МcrХ2 О2А1cХrИАКЕОЧХХcАcЛУХЕО8ЕАЕcМ82ЛМ8?c<МАП cБАrbМ4c2О2cБКАХЛЙА7ХМcЛУОМХ8cХЛБАД4ФtaЬ88cФrОrХbc АcМ82ЛМ8cР8Кr8ЕЛbc2cБАrbМХbЕc5rМКАБХХcХcХrИАКЕОМХР rАЛМХcМ82ЛМОccЛРbФ4cЕ8У7tcР8КАbМrАЛМbЕХcХc2А7ОЕХcХ Фt<О8МЛbcРcОД>8ПКОХ<8Л2А1cМ8АКХХc2А7ХКАРОrХbcАЛrА РrА1cМ8АКХ81c2АМАКА1cbРДb8МЛbcrХ2МАcХrА1c2О2c2ДА7c5 ДРt7cЫ8rrАrc8>АcМ8АК8Еc2А7ХКАРОrХbcХЛМА<rХ2ОcХЛБАД4ФtaМЛbcА<8r4cО2МХРrАc ХcФ78Л4"

# %%
from collections import Counter

# %% [markdown]
# Функция подсчета частот букв в тексте и создание списка из уникальных букв в исходном тексте с упорядоченнной частотой

# %%
def count_symbols() -> list:
    simvols = Counter(TEXT)
    dict_simvols = {}
    alfa_text = []
    print(dict_simvols)
    for item in simvols:
        simvols[item] = simvols[item] / len(TEXT)
        dict_simvols[item] = simvols[item]
        print(item, simvols[item])
    dict_simvols = dict(sorted(dict_simvols.items(), key=lambda x: x[1]))
    print("Упорядоченные буквы по возрастанию частоты")
    print(dict_simvols)
    x = list(dict_simvols.keys())
    print(x)
    return x

# %%
count_symbols()
# Out:
# {}
# 7 0.019230769230769232
# О 0.04423076923076923
# У 0.009615384615384616
# 8 0.07115384615384615
# c 0.13653846153846153
# r 0.057692307692307696
# Л 0.05384615384615385
# Б 0.025
# Ч 0.0038461538461538464
# Х 0.08846153846153847
# Д 0.026923076923076925
# М 0.06923076923076923
# t 0.015384615384615385
# b 0.03653846153846154
# А 0.1
# < 0.015384615384615385
# Р 0.025
# Е 0.03076923076923077
# 5 0.0057692307692307696
# 1 0.013461538461538462
#   0.019230769230769232
# К 0.032692307692307694
# 4 0.01730769230769231
# > 0.0057692307692307696
# ? 0.0038461538461538464
# 2 0.04038461538461539
# Ф 0.013461538461538462
# И 0.0057692307692307696
# П 0.0038461538461538464
# ̆ 0.0019230769230769232
# a 0.0038461538461538464
# Ь 0.0019230769230769232
# Ы 0.0019230769230769232
# Упорядоченные буквы по возрастанию частоты
# {'̆': 0.0019230769230769232, 'Ь': 0.0019230769230769232, 'Ы': 0.0019230769230769232, 'Ч': 0.0038461538461538464, '?': 0.0038461538461538464, 'П': 0.0038461538461538464, 'a': 0.0038461538461538464, '5': 0.0057692307692307696, '>': 0.0057692307692307696, 'И': 0.0057692307692307696, 'У': 0.009615384615384616, '1': 0.013461538461538462, 'Ф': 0.013461538461538462, 't': 0.015384615384615385, '<': 0.015384615384615385, '4': 0.01730769230769231, '7': 0.019230769230769232, ' ': 0.019230769230769232, 'Б': 0.025, 'Р': 0.025, 'Д': 0.026923076923076925, 'Е': 0.03076923076923077, 'К': 0.032692307692307694, 'b': 0.03653846153846154, '2': 0.04038461538461539, 'О': 0.04423076923076923, 'Л': 0.05384615384615385, 'r': 0.057692307692307696, 'М': 0.06923076923076923, '8': 0.07115384615384615, 'Х': 0.08846153846153847, 'А': 0.1, 'c': 0.13653846153846153}
# ['̆', 'Ь', 'Ы', 'Ч', '?', 'П', 'a', '5', '>', 'И', 'У', '1', 'Ф', 't', '<', '4', '7', ' ', 'Б', 'Р', 'Д', 'Е', 'К', 'b', '2', 'О', 'Л', 'r', 'М', '8', 'Х', 'А', 'c']
# ['̆',
#  'Ь',
#  'Ы',
#  'Ч',
#  '?',
#  'П',
#  'a',
#  '5',
#  '>',
#  'И',
#  'У',
#  '1',
#  'Ф',
#  't',
#  '<',
#  '4',
#  '7',
#  ' ',
#  'Б',
#  'Р',
#  'Д',
#  'Е',
#  'К',
#  'b',
#  '2',
#  'О',
#  'Л',
#  'r',
#  'М',
#  '8',
#  'Х',
#  'А',
#  'c']

# %% [markdown]
# Список букв, соответветствующих соответветвенно ключам частот букв. То есть каждая буква в этом списке ALF является ключом для букв зашифрованного текста

# %%
ALF = ['х', 'щ', 'ю', 'б', '-', 'ц', 'ф', 'г', 'э', 'ж', 'з', 'й', 'ч', 'у', 'ь', 'д', 'ы', 'в', 'п', 'л', 'м', 'р',
       'я', 'к', 'а', 'с', 'н', 'т', 'е', 'и', 'о', ' ']

# %% [markdown]
# Функция дешифрования.Меняет буквы из двух списков.

# %%
def chenging(new_text: str) -> str:
    list_alfa = count_symbols()
    ALF = ['х', 'щ', 'ц', '-', 'б', 'ю', 'э', 'г', 'ф', 'ж', 'й', 'з', 'у', 'ч', 'ь', 'д', 'ы', 'п', 'в', 'л', 'м', 'р',
           'я', 'к', 'а', 'с', 'н', 'т', 'е', 'и', 'о', ' ']
    len(ALF)
    i = 0
    new_text = new_text.replace(" ", "")
    for simvol in count_symbols():
        if simvol == 'Ы':
            new_text = new_text.replace(simvol, "ш")
        else:
            s = ALF[i]
            new_text = new_text.replace(simvol, ALF[i])
            i = i + 1
    print(new_text)
    return new_text

# %%
TEXT = chenging(TEXT)
# Out:
# {}
# 7 0.019230769230769232
# О 0.04423076923076923
# У 0.009615384615384616
# 8 0.07115384615384615
# c 0.13653846153846153
# r 0.057692307692307696
# Л 0.05384615384615385
# Б 0.025
# Ч 0.0038461538461538464
# Х 0.08846153846153847
# Д 0.026923076923076925
# М 0.06923076923076923
# t 0.015384615384615385
# b 0.03653846153846154
# А 0.1
# < 0.015384615384615385
# Р 0.025
# Е 0.03076923076923077
# 5 0.0057692307692307696
# 1 0.013461538461538462
#   0.019230769230769232
# К 0.032692307692307694
# 4 0.01730769230769231
# > 0.0057692307692307696
# ? 0.0038461538461538464
# 2 0.04038461538461539
# Ф 0.013461538461538462
# И 0.0057692307692307696
# П 0.0038461538461538464
# ̆ 0.0019230769230769232
# a 0.0038461538461538464
# Ь 0.0019230769230769232
# Ы 0.0019230769230769232
# Упорядоченные буквы по возрастанию частоты
# {'̆': 0.0019230769230769232, 'Ь': 0.0019230769230769232, 'Ы': 0.0019230769230769232, 'Ч': 0.0038461538461538464, '?': 0.0038461538461538464, 'П': 0.0038461538461538464, 'a': 0.0038461538461538464, '5': 0.0057692307692307696, '>': 0.0057692307692307696, 'И': 0.0057692307692307696, 'У': 0.009615384615384616, '1': 0.013461538461538462, 'Ф': 0.013461538461538462, 't': 0.015384615384615385, '<': 0.015384615384615385, '4': 0.01730769230769231, '7': 0.019230769230769232, ' ': 0.019230769230769232, 'Б': 0.025, 'Р': 0.025, 'Д': 0.026923076923076925, 'Е': 0.03076923076923077, 'К': 0.032692307692307694, 'b': 0.03653846153846154, '2': 0.04038461538461539, 'О': 0.04423076923076923, 'Л': 0.05384615384615385, 'r': 0.057692307692307696, 'М': 0.06923076923076923, '8': 0.07115384615384615, 'Х': 0.08846153846153847, 'А': 0.1, 'c': 0.13653846153846153}
# ['̆', 'Ь', 'Ы', 'Ч', '?', 'П', 'a', '5', '>', 'И', 'У', '1', 'Ф', 't', '<', '4', '7', ' ', 'Б', 'Р', 'Д', 'Е', 'К', 'b', '2', 'О', 'Л', 'r', 'М', '8', 'Х', 'А', 'c']
# {}
# 7 0.019230769230769232
# О 0.04423076923076923
# У 0.009615384615384616
# 8 0.07115384615384615
# c 0.13653846153846153
# r 0.057692307692307696
# Л 0.05384615384615385
# Б 0.025
# Ч 0.0038461538461538464
# Х 0.08846153846153847
# Д 0.026923076923076925
# М 0.06923076923076923
# t 0.015384615384615385
# b 0.03653846153846154
# А 0.1
# < 0.015384615384615385
# Р 0.025
# Е 0.03076923076923077
# 5 0.0057692307692307696
# 1 0.013461538461538462
#   0.019230769230769232
# К 0.032692307692307694
# 4 0.01730769230769231
# > 0.0057692307692307696
# ? 0.0038461538461538464
# 2 0.04038461538461539
# Ф 0.013461538461538462
# И 0.0057692307692307696
# П 0.0038461538461538464
# ̆ 0.0019230769230769232
# a 0.0038461538461538464
# Ь 0.0019230769230769232
# Ы 0.0019230769230769232
# Упорядоченные буквы по возрастанию частоты
# {'̆': 0.0019230769230769232, 'Ь': 0.0019230769230769232, 'Ы': 0.0019230769230769232, 'Ч': 0.0038461538461538464, '?': 0.0038461538461538464, 'П': 0.0038461538461538464, 'a': 0.0038461538461538464, '5': 0.0057692307692307696, '>': 0.0057692307692307696, 'И': 0.0057692307692307696, 'У': 0.009615384615384616, '1': 0.013461538461538462, 'Ф': 0.013461538461538462, 't': 0.015384615384615385, '<': 0.015384615384615385, '4': 0.01730769230769231, '7': 0.019230769230769232, ' ': 0.019230769230769232, 'Б': 0.025, 'Р': 0.025, 'Д': 0.026923076923076925, 'Е': 0.03076923076923077, 'К': 0.032692307692307694, 'b': 0.03653846153846154, '2': 0.04038461538461539, 'О': 0.04423076923076923, 'Л': 0.05384615384615385, 'r': 0.057692307692307696, 'М': 0.06923076923076923, '8': 0.07115384615384615, 'Х': 0.08846153846153847, 'А': 0.1, 'c': 0.13653846153846153}
# ['̆', 'Ь', 'Ы', 'Ч', '?', 'П', 'a', '5', '>', 'И', 'У', '1', 'Ф', 't', '<', '4', '7', ' ', 'Б', 'Р', 'Д', 'Е', 'К', 'b', '2', 'О', 'Л', 'r', 'М', '8', 'Х', 'А', 'c']
# даже неспециалисту ясно что в том числе и по этой причине рле не представляется оптимальнм алгоритмом сжатия- поскольку он не использует никакой информации о сжимаемом тексте- чтоб понять как происфходит сжатие использующее знания о тексте вернемся к понятиям энтропии и информативности текста  связь между вероятностями и кодами изучается в алгебраической теории кодирования основной теорией которой является никто иной как клод элвуд шеннон его теорем кодирования источника используются очень активно и здесь

# %% [markdown]
# Функция записи расшифрованного текста в файл

# %%
def write_text(TEXT):
    with open('deshifr.txt', "w+") as f:
        f.write(TEXT)

# %%
write_text(TEXT)

# %% [markdown]
# Расшифрованный текст:

# %%
print(TEXT)
# Out:
# даже неспециалисту ясно что в том числе и по этой причине рле не представляется оптимальнм алгоритмом сжатия- поскольку он не использует никакой информации о сжимаемом тексте- чтоб понять как происфходит сжатие использующее знания о тексте вернемся к понятиям энтропии и информативности текста  связь между вероятностями и кодами изучается в алгебраической теории кодирования основной теорией которой является никто иной как клод элвуд шеннон его теорем кодирования источника используются очень активно и здесь
